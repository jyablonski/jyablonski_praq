# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timezone, timedelta
import boto3
import pyarrow
import awswrangler as wr

# %%
# NBA season we will be analyzing
year = 2021
# URL page we will scraping (see image above)
url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html".format(year)
# this is the HTML from the given URL
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
url
# url is literlly just the url link
# Out:
# 'https://www.basketball-reference.com/leagues/NBA_2021_per_game.html'

# %%
html
# this is the httpresponse code we get after opening the url

# %%
# soup
# soup is the LITERAL HTML.  ITS HUNDREDS OF LINES LONG, THOUSANDS

# we need to grab just the elements we want.

# %%
# use findALL() to get the column headers
# soup.findAll('tr', limit=2)
# use getText()to extract the text we need into a list

# the tr group has th elements which are the headers we want data for.
headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]

# exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
headers = headers[1:]
headers
# Out:
# ['Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
# avoid the first header row
# the td elements have the actual data points we want.
rows = soup.findAll('tr')[1:]
player_stats = [[td.getText() for td in rows[i].findAll('td')]
            for i in range(len(rows))]

# %%
# combining the column headers and the data points together
stats = pd.DataFrame(player_stats, columns = headers)
stats['PTS'] = pd.to_numeric(stats['PTS'])

# %%
stats.sort_values('PTS', ascending = False).head(10)
# Out:
#                     Player Pos Age   Tm   G  GS    MP    FG   FGA   FG%  ...  \
# 156          Stephen Curry  PG  32  GSW  63  63  34.2  10.4  21.7  .482  ...
# 46            Bradley Beal  SG  27  WAS  60  60  35.8  11.2  23.0  .485  ...
# 410         Damian Lillard  PG  30  POR  67  67  35.8   9.0  19.9  .451  ...
# 196            Joel Embiid   C  26  PHI  51  51  31.1   9.0  17.6  .513  ...
# 17   Giannis Antetokounmpo  PF  26  MIL  61  61  33.0  10.3  18.0  .569  ...
# 177            Luka Dončić  PG  21  DAL  66  66  34.3   9.8  20.5  .479  ...
# 395            Zach LaVine  SG  25  CHI  58  58  35.1   9.8  19.4  .507  ...
# 714        Zion Williamson  PF  20  NOP  61  61  33.2  10.4  17.0  .611  ...
# 189           Kevin Durant  PF  32  BRK  35  32  33.1   9.3  17.2  .537  ...
# 328           Kyrie Irving  PG  28  BRK  54  54  34.9  10.2  20.1  .506  ...
#
#       FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 156  .916  0.5  5.0   5.5  5.8  1.2  0.1  3.4  1.9  32.0
# 46   .889  1.2  3.5   4.7  4.4  1.2  0.4  3.1  2.3  31.3
# 410  .928  0.5  3.7   4.2  7.5  0.9  0.3  3.0  1.5  28.8
# 196  .859  2.2  8.4  10.6  2.8  1.0  1.4  3.1  2.4  28.5
# 17   .685  1.6  9.4  11.0  5.9  1.2  1.2  3.4  2.8  28.1
# 177  .730  0.8  7.2   8.0  8.6  1.0  0.5  4.3  2.3  27.7
# 395  .849  0.6  4.4   5.0  4.9  0.8  0.5  3.5  2.4  27.4
# 714  .698  2.7  4.5   7.2  3.7  0.9  0.6  2.7  2.2  27.0
# 189  .882  0.4  6.7   7.1  5.6  0.7  1.3  3.4  2.0  26.9
# 328  .922  1.0  3.8   4.8  6.0  1.4  0.7  2.4  2.6  26.9
#
# [10 rows x 29 columns]

# %%
# datetimte stuff
today = datetime.now().date()
yesterday = today - timedelta(1)
day = (datetime.now() - timedelta(1)).day
month = (datetime.now() - timedelta(1)).month
year = (datetime.now() - timedelta(1)).year

# %%
#### BOX SCORE WEB SCRAPING
# https://www.basketball-reference.com/friv/dailyleaders.fcgi?month=07&day=17&year=2021&type=all

url = "https://www.basketball-reference.com/friv/dailyleaders.fcgi?month={}&day={}&year={}&type=all".format(month, day, year)
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
headers = headers[1:]
headers[2] = "Location"
headers[4] = "Outcome"
# headers
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-b4fa742d0d76> in <module>
# ----> 1 headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
#       2 headers = headers[1:]
#       3 headers[2] = "Location"
#       4 headers[4] = "Outcome"
#       5 # headers
#
# IndexError: list index out of range

# %%
rows = soup.findAll('tr')[1:]
player_stats = [[td.getText() for td in rows[i].findAll('td')]
            for i in range(len(rows))]

# %%
df2 = pd.DataFrame(player_stats, columns = headers)

# %%
df2[['FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc']] = df2[['FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc']].apply(pd.to_numeric)

# %%
df2.sort_values('PTS', ascending = False)
# Out:
#                    Player   Tm Location  Opp Outcome     MP  FG  FGA    FG%  \
# 2            Devin Booker  PHO           MIL       L  41:32  17   33  0.515
# 1   Giannis Antetokounmpo  MIL        @  PHO       W  40:34  14   23  0.609
# 5         Khris Middleton  MIL        @  PHO       W  44:23  12   23  0.522
# 0            Jrue Holiday  MIL        @  PHO       W  41:57  12   20  0.600
# 3              Chris Paul  PHO           MIL       L  35:21   9   15  0.600
# 4           Deandre Ayton  PHO           MIL       L  44:49   7   12  0.583
# 6         Pat Connaughton  MIL        @  PHO       W  33:23   4    6  0.667
# 7           Mikal Bridges  PHO           MIL       L  32:44   5    6  0.833
# 8             Jae Crowder  PHO           MIL       L  40:09   4    7  0.571
# 9            Bobby Portis  MIL        @  PHO       W  19:20   3    6  0.500
# 12            Brook Lopez  MIL        @  PHO       W  28:42   4    6  0.667
# 10          Cameron Payne  PHO           MIL       L  14:34   3    7  0.429
# 11        Cameron Johnson  PHO           MIL       L  21:52   2    3  0.667
# 13            P.J. Tucker  MIL        @  PHO       W  24:08   1    2  0.500
# 14           Torrey Craig  PHO           MIL       L   8:59   1    4  0.250
# 15            Jeff Teague  MIL        @  PHO       W   7:33   0    1  0.000
#
#     3P  ...  DRB  TRB AST STL BLK TOV  PF  PTS  +/-  GmSc
# 2    2  ...    3    4   3   2   1   2   5   40  +12  25.7
# 1    0  ...    4    9   6   0   0   0   2   32   -7  26.8
# 5    3  ...    7    7   5   0   0   4   3   29   +4  17.7
# 0    3  ...    3    4  13   3   1   2   4   27  +14  28.6
# 3    3  ...    2    2  11   0   1   1   5   21   -6  20.1
# 4    0  ...    7   10   1   1   2   2   4   20   +6  18.1
# 6    4  ...    5    6   0   0   0   0   0   14  +10  13.6
# 7    3  ...    4    4   1   2   1   2   1   13   +5  13.0
# 8    2  ...    4    5   3   2   0   0   3   10   -7  11.5
# 9    2  ...    0    3   0   2   0   0   0    9   +7  10.1
# 12   1  ...    6    6   0   0   0   3   2    9  +10   4.4
# 10   0  ...    3    4   4   2   0   0   1    6   -4   8.3
# 11   2  ...    2    4   0   0   0   1   0    6  -19   5.7
# 13   1  ...    1    1   1   1   0   1   5    3   -7   1.0
# 14   1  ...    2    2   0   0   0   0   1    3   -7   0.8
# 15   0  ...    0    1   1   1   0   1   1    0  -11   0.3
#
# [16 rows x 26 columns]

# %%
#### injury report
url = "https://www.basketball-reference.com/friv/injuries.fcgi"
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]

trs = soup.findAll('tr')[1:]
rows = []
for tr in trs:
    player_name = tr.find('a').text
    data = [player_name] + [x.text for x in tr.find_all('td')]
    rows.append(data)

injury_data = pd.DataFrame(rows, columns = headers)

# %%
injury_data
# Out:
#               Player                    Team             Update  \
# 0     Onyeka Okongwu           Atlanta Hawks  Wed, Jul 21, 2021
# 1       Jaylen Brown          Boston Celtics  Thu, May 13, 2021
# 2         Coby White           Chicago Bulls  Thu, Jun 10, 2021
# 3       Jamal Murray          Denver Nuggets  Thu, Jul 22, 2021
# 4      Klay Thompson   Golden State Warriors  Thu, Jul 22, 2021
# 5      James Wiseman   Golden State Warriors  Thu, Jul 22, 2021
# 6        T.J. Warren          Indiana Pacers  Thu, Mar 25, 2021
# 7   Donte DiVincenzo         Milwaukee Bucks  Fri, May 28, 2021
# 8     Jarrett Culver  Minnesota Timberwolves  Thu, Apr 29, 2021
# 9     Taurean Prince  Minnesota Timberwolves  Thu, Apr 22, 2021
# 10    Markelle Fultz           Orlando Magic   Wed, Jan 6, 2021
# 11    Jonathan Isaac           Orlando Magic   Fri, Mar 5, 2021
# 12       Dario Šarić            Phoenix Suns   Wed, Jul 7, 2021
# 13      Zach Collins       San Antonio Spurs  Tue, Jun 29, 2021
# 14     Pascal Siakam         Toronto Raptors  Fri, Jun 11, 2021
# 15       Deni Avdija      Washington Wizards  Fri, Apr 23, 2021
# 16     Thomas Bryant      Washington Wizards   Tue, Feb 2, 2021
#
#                                           Description
# 0   Out (Shoulder) - The Hawks announced that Okon...
# 1   Out (Wrist) - The Celtics announced that Brown...
# 2   Out (Shoulder) - The Bulls announced that Whit...
# 3   Out (Knee) - Murray is recovering from a torn ...
# 4   Out (Right Achilles) - Thompson is on track to...
# 5   Out (Knee) - Wiseman is on track to be ready b...
# 6   Out (Foot) - Warren underwent foot surgery and...
# 7   Out (Foot) - DiVincenzo suffered a tendon inju...
# 8   Out (Ankle) - The Timberwolves announced Culve...
# 9   Out (Ankle) - The Cavaliers announced F Taurea...
# 10  Out (Knee) - Fultz will miss the rest of the s...
# 11  Out (Knee) - Isaac is making progress with his...
# 12  Out (Knee) - The Suns announced that Sario has...
# 13  Out (Ankle) - The Blazers announced that Colli...
# 14  Out (Shoulder) - The Raptors announced Pascal ...
# 15  Out (Leg) - The Wizards announced that Avdija ...
# 16  Out (Left knee) - The Wizards announced that B...

# %%
# ALTERNATIVE
injury_data2 = pd.read_html(url)[0]

# %%
injury_data2
# Out:
#               Player                    Team             Update  \
# 0     Onyeka Okongwu           Atlanta Hawks  Wed, Jul 21, 2021
# 1       Jaylen Brown          Boston Celtics  Thu, May 13, 2021
# 2         Coby White           Chicago Bulls  Thu, Jun 10, 2021
# 3       Jamal Murray          Denver Nuggets  Thu, Jul 22, 2021
# 4      Klay Thompson   Golden State Warriors  Thu, Jul 22, 2021
# 5      James Wiseman   Golden State Warriors  Thu, Jul 22, 2021
# 6        T.J. Warren          Indiana Pacers  Thu, Mar 25, 2021
# 7   Donte DiVincenzo         Milwaukee Bucks  Fri, May 28, 2021
# 8     Jarrett Culver  Minnesota Timberwolves  Thu, Apr 29, 2021
# 9     Taurean Prince  Minnesota Timberwolves  Thu, Apr 22, 2021
# 10    Markelle Fultz           Orlando Magic   Wed, Jan 6, 2021
# 11    Jonathan Isaac           Orlando Magic   Fri, Mar 5, 2021
# 12       Dario Šarić            Phoenix Suns   Wed, Jul 7, 2021
# 13      Zach Collins       San Antonio Spurs  Tue, Jun 29, 2021
# 14     Pascal Siakam         Toronto Raptors  Fri, Jun 11, 2021
# 15       Deni Avdija      Washington Wizards  Fri, Apr 23, 2021
# 16     Thomas Bryant      Washington Wizards   Tue, Feb 2, 2021
#
#                                           Description
# 0   Out (Shoulder) - The Hawks announced that Okon...
# 1   Out (Wrist) - The Celtics announced that Brown...
# 2   Out (Shoulder) - The Bulls announced that Whit...
# 3   Out (Knee) - Murray is recovering from a torn ...
# 4   Out (Right Achilles) - Thompson is on track to...
# 5   Out (Knee) - Wiseman is on track to be ready b...
# 6   Out (Foot) - Warren underwent foot surgery and...
# 7   Out (Foot) - DiVincenzo suffered a tendon inju...
# 8   Out (Ankle) - The Timberwolves announced Culve...
# 9   Out (Ankle) - The Cavaliers announced F Taurea...
# 10  Out (Knee) - Fultz will miss the rest of the s...
# 11  Out (Knee) - Isaac is making progress with his...
# 12  Out (Knee) - The Suns announced that Sario has...
# 13  Out (Ankle) - The Blazers announced that Colli...
# 14  Out (Shoulder) - The Raptors announced Pascal ...
# 15  Out (Leg) - The Wizards announced that Avdija ...
# 16  Out (Left knee) - The Wizards announced that B...

# %%
##### transactions
url = "https://www.basketball-reference.com/leagues/NBA_2021_transactions.html"
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]

trs = soup.findAll('tr')[1:]
rows = []
for tr in trs:
    player_name = tr.find('a').text
    data = [player_name] + [x.text for x in tr.find_all('td')]
    rows.append(data)

injury_data = pd.DataFrame(rows, columns = headers)

# %%
#for tr in trs:
    #data = tr.findAll('p')
    # for p in data:
        # print(p.text)
    # print(tr.find('span').text)
    # print(x.text for x in tr.find('p'))

# %%
trs = soup.findAll('li')[71:]
rows = []
for tr in trs:
    date = tr.find('span').text
    data = tr.find('p')
    data2 = [date] + [data]
    rows.append(data2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-d9314a4f5e6b> in <module>
#       2 rows = []
#       3 for tr in trs:
# ----> 4     date = tr.find('span').text
#       5     data = tr.find('p')
#       6     data2 = [date] + [data]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
trs = soup.findAll('li')[71:]
rows = []
mylist = []
for tr in trs:
    date = tr.find('span').text
    data = tr.findAll('p')
    for p in data:
        if p is not None:
            mylist.append(p.text)
    data3 = [date] + [mylist]
    rows.append(data3)
    mylist = []
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-154-fae8e66739ae> in <module>
#       3 mylist = []
#       4 for tr in trs:
# ----> 5     date = tr.find('span').text
#       6     data = tr.findAll('p')
#       7     for p in data:
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
trs = soup.findAll('li')[71:]
rows = []
mylist = []
for tr in trs:
    date = tr.find('span')
    if date is not None: # needed bc span can be null (multi <p> elements per span)
        date = date.text
    data = tr.findAll('p')
    for p in data:
        mylist.append(p.text)
    data3 = [date] + [mylist]
    rows.append(data3)
    mylist = []

# %%
transactions = pd.DataFrame(rows)
transactions.columns = ['Date', 'Transaction']
transactions = transactions.explode('Transaction')
transactions['Date'] = pd.to_datetime(transactions['Date'])
transactions = transactions.query('Date != "NaN"')
transactions
# Out:
#           Date                                        Transaction
# 0   2021-06-28    The Dallas Mavericks hired Nico Harrison as GM.
# 0   2021-06-28  The Dallas Mavericks hired Jason Kidd as Head ...
# 1   2021-06-18  The Boston Celtics traded Kemba Walker, a 2021...
# 2   2021-06-17  Rick Carlisle resigns as Head Coach for Dallas...
# 3   2021-06-16      The Dallas Mavericks fired Donn Nelson as GM.
# ..         ...                                                ...
# 135 2020-11-18  The Orlando Magic traded a 2020 2nd round draf...
# 136 2020-11-17  The Utah Jazz traded Ante Tomic and a 2020 1st...
# 137 2020-11-16  The Orlando Magic signed Chuma Okeke to a mult...
# 137 2020-11-16  The Oklahoma City Thunder traded Abdel Nader a...
# 138 2020-11-11  The Oklahoma City Thunder hired Mark Daigneaul...
#
# [820 rows x 2 columns]

# %%
# random web scrape i found - might be useful
import csv 
import requests
from bs4 import BeautifulSoup
import csv
import re
url_list = ['https://basketball.realgm.com/player/player/Summary/2',
            'https://basketball.realgm.com/player/player/Summary/1']

for url in url_list:
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    player = soup.find_all('div', class_='wrapper clearfix container')[0]

    playerprofile = re.sub(
        r'\n\s*\n', r'\n', player.get_text().strip(), flags=re.M)

    output = playerprofile + "\n"

# %%
### SCHEDULE
raw_df = pd.DataFrame()
month_list = ['december', 'january', 'february', 'march', 'april', 'may', 'june', 'july']
url = "https://www.basketball-reference.com/leagues/NBA_2021_games-december.html"
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
headers = [th.getText() for th in soup.findAll('tr')[0].findAll('th')]
# headers = headers[1:]
headers[6] = 'boxScoreLink'
headers[7] = 'isOT'
headers = headers[1:]

# %%
rows = soup.findAll('tr')[1:]
player_stats = [[td.getText() for td in rows[i].findAll('td')]
            for i in range(len(rows))]

# %%
rows = soup.findAll('tr')[1:]
date_info = [[th.getText() for th in rows[i].findAll('th')]
            for i in range(len(rows))]

game_info = [[td.getText() for td in rows[i].findAll('td')]
            for i in range(len(rows))]
date_info = [i[0] for i in date_info] # removes brackets from each element.
# date_info

# %%
schedule = pd.DataFrame(game_info, columns = headers)
schedule['Date'] = date_info

# %%
# variables in functions are local by default
# variables outside of functions are global by default
# to modify a global variable in local function, we have to explicity label it as a global var.
schedule_df = pd.DataFrame()
def schedule_scraper(month):
    global schedule_df
    url = "https://www.basketball-reference.com/leagues/NBA_2021_games-{}.html".format(month)
    html = urlopen(url)
    soup = BeautifulSoup(html)

    headers = [th.getText() for th in soup.findAll('tr')[0].findAll('th')]

    headers[6] = 'boxScoreLink'
    headers[7] = 'isOT'
    headers = headers[1:]

    rows = soup.findAll('tr')[1:]
    date_info = [[th.getText() for th in rows[i].findAll('th')]
            for i in range(len(rows))]

    game_info = [[td.getText() for td in rows[i].findAll('td')]
            for i in range(len(rows))]
    date_info = [i[0] for i in date_info]

    schedule = pd.DataFrame(game_info, columns = headers)
    schedule['Date'] = date_info
    
    # join_df = join_df.append(schedule)
    schedule_df = schedule_df.append(schedule)
    # return(join_df)

# %%
schedule_df = pd.DataFrame()
schedule_scraper('february')

# %%
schedule_df = pd.DataFrame()
for month in month_list:
    schedule_scraper(month)

# %%
raw_df.tail(5)
# Out:
#   Start (ET)  Visitor/Neutral  PTS     Home/Neutral  PTS boxScoreLink isOT  \
# 3      9:00p  Milwaukee Bucks  108     Phoenix Suns  118    Box Score
# 4      8:00p     Phoenix Suns  100  Milwaukee Bucks  120    Box Score
# 5      9:00p     Phoenix Suns  103  Milwaukee Bucks  109    Box Score
# 6      9:00p  Milwaukee Bucks  123     Phoenix Suns  119    Box Score
# 7      9:00p     Phoenix Suns   98  Milwaukee Bucks  105    Box Score
#
#   Attend. Notes               Date
# 3  16,583         Thu, Jul 8, 2021
# 4  16,637        Sun, Jul 11, 2021
# 5  16,911        Wed, Jul 14, 2021
# 6  16,562        Sat, Jul 17, 2021
# 7  17,397        Tue, Jul 20, 2021

# %%
print(f"hi it is {month} haa")
aab = f'hi it is {month} haa'
print(aab)
# f('hii {var1} haa' functionality works for both print statements and variable dec
# Out:
# hi it is july haa
# hi it is july haa

# %%
print('hi it is {} month') #.format(month) will give an error
aac = 'hi it is {} haa'.format(month)
print(aab)
# {} .format only works for variable dec
# Out:
# hi it is {} month
# hi it is july haa

# %%
#### Team advanced stats
url = "https://www.basketball-reference.com/leagues/NBA_2021.html"
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
# NOT NEEDED
divTag = soup.find("div", {"id": "div_advanced-team"})
th_all = divTag.find_all('th')
result = []
for th in th_all:
    result.extend(th.find_all(text='A'))

bby = divTag.select("th td")

# %%
df_list = pd.read_html(url)

# %%
advanced_stats = pd.DataFrame(df_list[10])
advanced_stats.drop(columns=advanced_stats.columns[0], 
        axis=1, 
        inplace=True)

advanced_stats.columns = ['Team', 'Age', 'W', 'L', 'PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORTG', 'DRTG', 'NRTG', 'Pace', 'FTr', '3PAr', 'TS%', 'bby1', 'eFG%', 'TOV%', 'ORB%', 'FT/FGA', 'bby2', 'eFG%_opp', 'TOV%_opp', 'DRB%_opp', 'FT/FGA_opp', 'bby3', 'Arena', 'Attendance', 'Att/Game']
advanced_stats.drop(['bby1', 'bby2', 'bby3'], axis = 1, inplace = True)
# advanced_stats.head(5)

# %%
# SQL STUFF
import sqlalchemy
from mysql.connector import Error
import os

def create_connection():
    connection = None
    try:
        connection = sqlalchemy.create_engine('mysql+mysqlconnector://' + os.environ.get('USER') + ':' + os.environ.get('PW') + '@' + os.environ.get('IP') + ':' + os.environ.get('PORT') + '/' + os.environ.get('DB'),
                     echo = False)
        print(f"Connection to Jacob's RDS MySQL {os.environ.get('DB')} DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

# connection = create_connection("localhost", "root", "")

# %%
connection = create_connection()
# Out:
# Connection to Jacob's RDS MySQL aws_database DB successful

# %%
# unnecessary for sqlalchemy, only used for mysql.connector + cursor connections
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query executed successfully")
    except Error as e:
        print(f"The error '{e}' occurred")

# %%
all_tables = pd.read_sql_query('SHOW TABLES FROM aws_database;', connection)
all_tables
# Out:
#    Tables_in_aws_database
# 0    aws_adv_player_stats
# 1         aws_cleaned_pbp
# 2            aws_gamelogs
# 3            aws_injuries
# 4        aws_my_cron_date
# 5            aws_new_odds
# 6             aws_odds_df
# 7   aws_opponent_shooting
# 8             aws_raw_pbp
# 9   aws_raw_pbp_yesterday
# 10        my_python_table

# %%
odds = pd.read_sql_query('SELECT * FROM aws_new_odds;', connection)
odds
# Out:
#     row_names                  team team_acc              opp  moneyline  \
# 0           1         Atlanta Hawks      ATL              PHI        225
# 1           2    Philadelphia 76ers      PHI              ATL       -278
# 2           3  Los Angeles Clippers      LAC              UTA        128
# 3           4             Utah Jazz      UTA              LAC       -155
# 4           1        Denver Nuggets      DEN              PHX        170
# ..        ...                   ...      ...              ...        ...
# 95          2       Milwaukee Bucks      MIL              PHX       -177
# 96          1          Phoenix Suns      PHX              MIL        145
# 97          2       Milwaukee Bucks      MIL              PHX       -177
# 98          1          Phoenix Suns     None  Milwaukee Bucks        175
# 99          2       Milwaukee Bucks     None     Phoenix Suns       -210
#
#     spread overunder  team_pts  game_id        date
# 0      6.5      over     108.0        1  2021-06-08
# 1     -6.5     under     113.0        1  2021-06-08
# 2      3.0      over     112.0        2  2021-06-08
# 3     -3.0     under     109.0        2  2021-06-08
# 4      5.0      over     113.0        1  2021-06-09
# ..     ...       ...       ...      ...         ...
# 95    -4.0     under     109.0        1  2021-07-09
# 96     4.0      over     112.0        1  2021-07-12
# 97    -4.0     under     109.0        1  2021-07-12
# 98     5.0      over     110.0        1  2021-07-18
# 99    -5.0     under     110.0        1  2021-07-18
#
# [100 rows x 10 columns]

# %%
odds.to_sql(con = connection, name = "my_python_table_2", index = False, if_exists = "replace")

# %%
odds2 = pd.read_sql_query('SELECT * FROM my_python_table_2;', con = connection)

# %%
time_now = pd.Series(datetime.now())
time_df = pd.DataFrame()
time_df = time_df.append(time_now, ignore_index = True)
time_df.to_sql(con = connection, name = "my_python_time_table", index = False, if_exists = "append")

# %%
time_df.to_sql(con = connection, name = "my_python_time_table", index = False, if_exists = "replace")

# %%
odds_sql = pd.read_sql_query('SELECT * FROM my_python_time_table;', connection)
odds_sql

# %%
# append rows of your local dataframe to an EXISTING sql table
time_df.to_sql(con = connection, name = "my_python_time_table",
               index = False, if_exists = "append")

# overwrite your EXISTING sql table with the new dataframe.
time_df.to_sql(con = connection, name = "my_python_time_table",
               index = False, if_exists = "replace")

# %%
# S3 STUFF
s3 = boto3.resource(
    service_name ='s3',
    region_name = os.getenv('AWS_REGION'),
    aws_access_key_id = os.getenv('AWS_KEY'),
    aws_secret_access_key = os.getenv('AWS_SECRET')
)

# %%
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# mygamelogsbucket
# thebucketofjacob2020

# %%
advanced_stats.to_parquet('advanced_stats.parquet')

# uploading a file to the bucket mygamelogsbucket
s3.Bucket('mygamelogsbucket').upload_file(Filename = 'foo.parquet', Key = 'you_dont_need_extension')

# %%
# works but spits out error.
wr.s3.to_parquet(
    df = advanced_stats,
    path = "s3://mygamelogsbucket/my-advanced-stats4.parquet"
    #path2 = "s3://mygamelogsbucket/key/my-advanced-stats3" will make a folder called key
    # and put the my-advanced-stats3 file in the key folder.
)
# Out:
# {'paths': ['s3://mygamelogsbucket/my-advanced-stats4.parquet'],
#  'partitions_values': {}}

# %%
gamelogs_s3 = s3.Bucket('mygamelogsbucket').Object('bby.csv').get()
gamelogs_s3 = pd.read_csv(gamelogs_s3['Body'], index_col = 0)

# %%
gamelogs_s3.tail(5)
# Out:
#            Season        Date    GameID  TeamGamesPlayed Team  isB2B  \
# row_names
# 22           2021  2021-05-20  52000201                2  WAS    NaN
# 23           2021  2021-05-20  52000201                2  WAS    NaN
# 24           2021  2021-05-20  52000201                2  IND    NaN
# 25           2021  2021-05-20  52000201                2  WAS    NaN
# 26           2021  2021-05-20  52000201                2  WAS    NaN
#
#            isB2BFirst  isB2BSecond Location  DaysRest  ... DREB TRB AST  STL  \
# row_names                                              ...
# 22                NaN          NaN        H         1  ...    3   3   0    2
# 23                NaN          NaN        H         1  ...    7   7   2    1
# 24                NaN          NaN        A         1  ...    2   3   3    1
# 25                NaN          NaN        H         1  ...    5   5   4    0
# 26                NaN          NaN        H         1  ...    1   3   0    0
#
#            BLK  TOV  PF  PTS  PlusMinus                Type
# row_names
# 22           0    1   2   14         17  Play-In Tournament
# 23           1    1   1    4         11  Play-In Tournament
# 24           1    1   2    6        -14  Play-In Tournament
# 25           1    4   0   25         18  Play-In Tournament
# 26           1    0   1    9          7  Play-In Tournament
#
# [5 rows x 38 columns]

# %%
# works but spits out error.
wr.s3.to_parquet(
    df = gamelogs_s3,
    path = "s3://mygamelogsbucket/bby.parquet"
    #path2 = "s3://mygamelogsbucket/key/my-advanced-stats3" will make a folder called key
    # and put the my-advanced-stats3 file in the key folder.
)
# Out:
# {'paths': ['s3://mygamelogsbucket/bby.parquet'], 'partitions_values': {}}

# %%
s3_df_parquet = wr.s3.read_parquet("s3://mygamelogsbucket/bby.parquet")
# s3_df_parquet2 = pd.read_parquet("s3://mygamelogsbucket/bby.parquet")
# need different permissions to access this.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\fsspec\registry.py in get_filesystem_class(protocol)
#     210         try:
# --> 211             register_implementation(protocol, _import_class(bit["class"]))
#     212         except ImportError as e:
#
# ~\anaconda3\lib\site-packages\fsspec\registry.py in _import_class(cls, minv)
#     225
# --> 226     mod = importlib.import_module(mod)
#     227     if minversion:
#
# ~\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 's3fs'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-b33efbd67c01> in <module>
#       1 s3_df_parquet = wr.s3.read_parquet("s3://mygamelogsbucket/bby.parquet")
# ----> 2 s3_df_parquet2 = pd.read_parquet("s3://mygamelogsbucket/bby.parquet")
#
# ~\anaconda3\lib\site-packages\pandas\io\parquet.py in read_parquet(path, engine, columns, use_nullable_dtypes, **kwargs)
#     457     """
#     458     impl = get_engine(engine)
# --> 459     return impl.read(
#     460         path, columns=columns, use_nullable_dtypes=use_nullable_dtypes, **kwargs
#     461     )
#
# ~\anaconda3\lib\site-packages\pandas\io\parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     212                 )
#     213
# --> 214         path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     215             path,
#     216             kwargs.pop("filesystem", None),
#
# ~\anaconda3\lib\site-packages\pandas\io\parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#      64         fsspec = import_optional_dependency("fsspec")
#      65
# ---> 66         fs, path_or_handle = fsspec.core.url_to_fs(
#      67             path_or_handle, **(storage_options or {})
#      68         )
#
# ~\anaconda3\lib\site-packages\fsspec\core.py in url_to_fs(url, **kwargs)
#     369     else:
#     370         protocol = split_protocol(url)[0]
# --> 371         cls = get_filesystem_class(protocol)
#     372
#     373         options = cls._get_kwargs_from_urls(url)
#
# ~\anaconda3\lib\site-packages\fsspec\registry.py in get_filesystem_class(protocol)
#     211             register_implementation(protocol, _import_class(bit["class"]))
#     212         except ImportError as e:
# --> 213             raise ImportError(bit["err"]) from e
#     214     cls = registry[protocol]
#     215     if getattr(cls, "protocol", None) in ("abstract", None):
#
# ImportError: Install s3fs to access S3
