# %%
import os
import pandas as pd
import boto3
import awswrangler as wr
from datetime import datetime

from sqlalchemy import exc, create_engine
# okay so if validated, then split up the string into 4 parts: the bucket, validated, month, and file name.
# then read the parquet file in, validate the schema again, and then store it to sql.
# the sql will be named aws_adv_stats_source in some random new bucket
# make sure the sql tables are created in pgadmin first.

# %%
def sql_connection(rds_schema: str):
    """
    SQL Connection function connecting to my postgres db with schema = nba_source where initial data in ELT lands
    Args:
        None
    Returns:
        SQL Connection variable to schema: nba_source in my PostgreSQL DB
    """
    RDS_USER = os.environ.get("RDS_USER")
    RDS_PW = os.environ.get("RDS_PW")
    RDS_IP = os.environ.get("IP")
    RDS_DB = os.environ.get("RDS_DB")
    try:
        connection = create_engine(
            f"postgresql+psycopg2://{RDS_USER}:{RDS_PW}@{RDS_IP}:5432/{RDS_DB}",
            connect_args={"options": f"-csearch_path={rds_schema}"},
            # defining schema to connect to
            echo=False,
        )
        print(f"SQL Connection to schema: {rds_schema} Successful")
        return connection
    except exc.SQLAlchemyError as e:
        print(f"SQL Connection to schema: {rds_schema} Failed, Error: {e}")
        return e

def write_to_sql(con, table_name: str, df: pd.DataFrame, table_type: str):
    """
    SQL Table function to write a pandas data frame in aws_dfname_source format
    Args:
        data: The Pandas DataFrame to store in SQL
        table_type: Whether the table should replace or append to an existing SQL Table under that name
    Returns:
        Writes the Pandas DataFrame to a Table in Snowflake in the {nba_source} Schema we connected to.
    """
    try:
        if len(df) == 0:
            print(f"{table_name} is empty, not writing to SQL")
        elif df.schema == "Validated":
            df.to_sql(
                con=con,
                name=f"aws_{table_name}_source",
                index=False,
                if_exists=table_type,
            )
            print(f"Writing {len(df)} {table_name} rows to aws_{table_name}_source to SQL")
        else:
            print(f"{table_name} Schema Invalidated, not writing to SQL")
    except BaseException as error:
        print(f"SQL Write Script Failed, {error}")
        return error

# %%
aws_conn = sql_connection('s3_ingestion_prac')
# Out:
# SQL Connection to schema: s3_ingestion_prac Successful

# %%
bucket_name = 'jacobsbucket97'

def get_s3_files(bucket: str):
    try:
        s3_resource = boto3.resource('s3')
        bucket = s3_resource.Bucket(name = bucket)
        s3_keys = list(s3_object.key for s3_object in bucket.objects.all())
        print(f"Returning {len(s3_keys)} s3 files")
        return s3_keys
    except BaseException as e:
        print(f"Error Occurred, {e}")
        raise e

s3_keys2 = get_s3_files(bucket_name)

# %%
s3_keys = s3_keys2[0]
data_type = s3_keys.split('/')[0]
valid_type = s3_keys.split('/')[1]
month = s3_keys.split('/')[2]
file_name = s3_keys.split('/')[3]

# %%
s3_keys_1 = s3_keys[:1] # select the very first element of a list and keep it in a list

# %%
def execute_reingestion(conn, s3_files):
    try:
        for i in s3_files:
            if 'validated' in i:
                if len(i.split('/')) == 4:  # the string should match this schema and have 4 unique parts, if not then dont ingest
                    data_type = i.split('/')[0]
                    file_name = i.split('/')[3]
                    df = wr.s3.read_parquet(path = f's3://{bucket_name}/{i}')
                    df['file_name'] = file_name
                    df['upload_time'] = datetime.now()
                    df.schema = 'Validated'
                    write_to_sql(conn, data_type, df, "append")
    except BaseException as e:
        print(f"Error Occurred, {e}")
        raise e

# %%
execute_reingestion(aws_conn, s3_keys)
# Out:
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 30 adv_stats rows to aws_adv_stats_source to SQL
# Writing 189 boxscores rows to aws_boxscores_source to SQL
# Writing 144 boxscores rows to aws_boxscores_source to SQL
# Writing 168 boxscores rows to aws_boxscores_source to SQL
# Writing 157 boxscores rows to aws_boxscores_source to SQL
# Writing 119 boxscores rows to aws_boxscores_source to SQL
# Writing 176 boxscores rows to aws_boxscores_source to SQL
# Writing 140 boxscores rows to aws_boxscores_source to SQL
# Writing 195 boxscores rows to aws_boxscores_source to SQL
# Writing 121 boxscores rows to aws_boxscores_source to SQL
# Writing 161 boxscores rows to aws_boxscores_source to SQL
# Writing 166 boxscores rows to aws_boxscores_source to SQL
# Writing 127 boxscores rows to aws_boxscores_source to SQL
# Writing 256 boxscores rows to aws_boxscores_source to SQL
# Writing 44 boxscores rows to aws_boxscores_source to SQL
# Writing 207 boxscores rows to aws_boxscores_source to SQL
# Writing 144 boxscores rows to aws_boxscores_source to SQL
# Writing 157 boxscores rows to aws_boxscores_source to SQL
# Writing 182 boxscores rows to aws_boxscores_source to SQL
# Writing 87 boxscores rows to aws_boxscores_source to SQL
# Writing 259 boxscores rows to aws_boxscores_source to SQL
# Writing 20 boxscores rows to aws_boxscores_source to SQL
# Writing 257 boxscores rows to aws_boxscores_source to SQL
# Writing 88 boxscores rows to aws_boxscores_source to SQL
# Writing 185 boxscores rows to aws_boxscores_source to SQL
# Writing 181 boxscores rows to aws_boxscores_source to SQL
# Writing 84 boxscores rows to aws_boxscores_source to SQL
# Writing 234 boxscores rows to aws_boxscores_source to SQL
# Writing 107 boxscores rows to aws_boxscores_source to SQL
# Writing 147 boxscores rows to aws_boxscores_source to SQL
# Writing 167 boxscores rows to aws_boxscores_source to SQL
# Writing 142 boxscores rows to aws_boxscores_source to SQL
# Writing 169 boxscores rows to aws_boxscores_source to SQL
# Writing 98 injury_data rows to aws_injury_data_source to SQL
# Writing 104 injury_data rows to aws_injury_data_source to SQL
# Writing 98 injury_data rows to aws_injury_data_source to SQL
# Writing 93 injury_data rows to aws_injury_data_source to SQL
# Writing 105 injury_data rows to aws_injury_data_source to SQL
# Writing 102 injury_data rows to aws_injury_data_source to SQL
# Writing 109 injury_data rows to aws_injury_data_source to SQL
# Writing 108 injury_data rows to aws_injury_data_source to SQL
# Writing 114 injury_data rows to aws_injury_data_source to SQL
# Writing 110 injury_data rows to aws_injury_data_source to SQL
# Writing 108 injury_data rows to aws_injury_data_source to SQL
# Writing 107 injury_data rows to aws_injury_data_source to SQL
# Writing 102 injury_data rows to aws_injury_data_source to SQL
# Writing 114 injury_data rows to aws_injury_data_source to SQL
# Writing 104 injury_data rows to aws_injury_data_source to SQL
# Writing 125 injury_data rows to aws_injury_data_source to SQL
# Writing 115 injury_data rows to aws_injury_data_source to SQL
# Writing 107 injury_data rows to aws_injury_data_source to SQL
# Writing 102 injury_data rows to aws_injury_data_source to SQL
# Writing 110 injury_data rows to aws_injury_data_source to SQL
# Writing 103 injury_data rows to aws_injury_data_source to SQL
# Writing 106 injury_data rows to aws_injury_data_source to SQL
# Writing 112 injury_data rows to aws_injury_data_source to SQL
# Writing 111 injury_data rows to aws_injury_data_source to SQL
# Writing 110 injury_data rows to aws_injury_data_source to SQL
# Writing 108 injury_data rows to aws_injury_data_source to SQL
# Writing 110 injury_data rows to aws_injury_data_source to SQL
# Writing 113 injury_data rows to aws_injury_data_source to SQL
# Writing 114 injury_data rows to aws_injury_data_source to SQL
# Writing 123 injury_data rows to aws_injury_data_source to SQL
# Writing 110 injury_data rows to aws_injury_data_source to SQL
# Writing 110 injury_data rows to aws_injury_data_source to SQL
# Writing 14 odds rows to aws_odds_source to SQL
# Writing 16 odds rows to aws_odds_source to SQL
# Writing 14 odds rows to aws_odds_source to SQL
# Writing 12 odds rows to aws_odds_source to SQL
# Writing 16 odds rows to aws_odds_source to SQL
# Writing 14 odds rows to aws_odds_source to SQL
# Writing 18 odds rows to aws_odds_source to SQL
# Writing 12 odds rows to aws_odds_source to SQL
# Writing 16 odds rows to aws_odds_source to SQL
# Writing 16 odds rows to aws_odds_source to SQL
# Writing 12 odds rows to aws_odds_source to SQL
# Writing 26 odds rows to aws_odds_source to SQL
# Writing 4 odds rows to aws_odds_source to SQL
# Writing 20 odds rows to aws_odds_source to SQL
# Writing 14 odds rows to aws_odds_source to SQL
# Writing 16 odds rows to aws_odds_source to SQL
# Writing 18 odds rows to aws_odds_source to SQL
# Writing 8 odds rows to aws_odds_source to SQL
# Writing 24 odds rows to aws_odds_source to SQL
# Writing 2 odds rows to aws_odds_source to SQL
# Writing 24 odds rows to aws_odds_source to SQL
# Writing 8 odds rows to aws_odds_source to SQL
# Writing 18 odds rows to aws_odds_source to SQL
# Writing 18 odds rows to aws_odds_source to SQL
# Writing 8 odds rows to aws_odds_source to SQL
# Writing 22 odds rows to aws_odds_source to SQL
# Writing 10 odds rows to aws_odds_source to SQL
# Writing 14 odds rows to aws_odds_source to SQL
# Writing 16 odds rows to aws_odds_source to SQL
# Writing 14 odds rows to aws_odds_source to SQL
# Writing 18 odds rows to aws_odds_source to SQL
# Writing 10 odds rows to aws_odds_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 30 opp_stats rows to aws_opp_stats_source to SQL
# Writing 1201 pbp_data rows to aws_pbp_data_source to SQL
# Writing 919 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1020 pbp_data rows to aws_pbp_data_source to SQL
# Writing 910 pbp_data rows to aws_pbp_data_source to SQL
# Writing 751 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1032 pbp_data rows to aws_pbp_data_source to SQL
# Writing 896 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1138 pbp_data rows to aws_pbp_data_source to SQL
# Writing 759 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1078 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1053 pbp_data rows to aws_pbp_data_source to SQL
# Writing 789 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1498 pbp_data rows to aws_pbp_data_source to SQL
# Writing 249 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1301 pbp_data rows to aws_pbp_data_source to SQL
# Writing 903 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1042 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1215 pbp_data rows to aws_pbp_data_source to SQL
# Writing 532 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1537 pbp_data rows to aws_pbp_data_source to SQL
# Writing 137 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1522 pbp_data rows to aws_pbp_data_source to SQL
# Writing 520 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1099 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1146 pbp_data rows to aws_pbp_data_source to SQL
# Writing 490 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1397 pbp_data rows to aws_pbp_data_source to SQL
# Writing 646 pbp_data rows to aws_pbp_data_source to SQL
# Writing 849 pbp_data rows to aws_pbp_data_source to SQL
# Writing 982 pbp_data rows to aws_pbp_data_source to SQL
# Writing 878 pbp_data rows to aws_pbp_data_source to SQL
# Writing 1160 pbp_data rows to aws_pbp_data_source to SQL
# Writing 6476 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6044 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6662 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6975 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5177 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5509 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5074 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6250 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6630 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6549 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6519 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6621 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5008 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 7479 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5431 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5272 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 7760 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6592 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5542 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 7957 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5780 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6166 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5176 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6631 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 7205 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5622 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 7335 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 6387 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5969 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5992 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5524 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 5680 reddit_comment_data rows to aws_reddit_comment_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 27 reddit_data rows to aws_reddit_data_source to SQL
# Writing 592 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 592 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 592 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 593 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 593 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 594 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 594 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 594 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 594 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 594 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 595 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 595 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 595 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 595 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 595 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 595 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 596 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 597 shooting_stats rows to aws_shooting_stats_source to SQL
# Writing 739 stats rows to aws_stats_source to SQL
# Writing 745 stats rows to aws_stats_source to SQL
# Writing 751 stats rows to aws_stats_source to SQL
# Writing 755 stats rows to aws_stats_source to SQL
# Writing 758 stats rows to aws_stats_source to SQL
# Writing 759 stats rows to aws_stats_source to SQL
# Writing 762 stats rows to aws_stats_source to SQL
# Writing 765 stats rows to aws_stats_source to SQL
# Writing 765 stats rows to aws_stats_source to SQL
# Writing 767 stats rows to aws_stats_source to SQL
# Writing 771 stats rows to aws_stats_source to SQL
# Writing 776 stats rows to aws_stats_source to SQL
# Writing 776 stats rows to aws_stats_source to SQL
# Writing 778 stats rows to aws_stats_source to SQL
# Writing 778 stats rows to aws_stats_source to SQL
# Writing 780 stats rows to aws_stats_source to SQL
# Writing 780 stats rows to aws_stats_source to SQL
# Writing 781 stats rows to aws_stats_source to SQL
# Writing 782 stats rows to aws_stats_source to SQL
# Writing 782 stats rows to aws_stats_source to SQL
# Writing 784 stats rows to aws_stats_source to SQL
# Writing 784 stats rows to aws_stats_source to SQL
# Writing 784 stats rows to aws_stats_source to SQL
# Writing 784 stats rows to aws_stats_source to SQL
# Writing 784 stats rows to aws_stats_source to SQL
# Writing 784 stats rows to aws_stats_source to SQL
# Writing 784 stats rows to aws_stats_source to SQL
# Writing 787 stats rows to aws_stats_source to SQL
# Writing 789 stats rows to aws_stats_source to SQL
# Writing 791 stats rows to aws_stats_source to SQL
# Writing 791 stats rows to aws_stats_source to SQL
# Writing 791 stats rows to aws_stats_source to SQL
# Writing 791 stats rows to aws_stats_source to SQL
# Writing 1599 transactions rows to aws_transactions_source to SQL
# Writing 1599 transactions rows to aws_transactions_source to SQL
# Writing 1599 transactions rows to aws_transactions_source to SQL
# Writing 1616 transactions rows to aws_transactions_source to SQL
# Writing 1623 transactions rows to aws_transactions_source to SQL
# Writing 1627 transactions rows to aws_transactions_source to SQL
# Writing 1636 transactions rows to aws_transactions_source to SQL
# Writing 1637 transactions rows to aws_transactions_source to SQL
# Writing 1637 transactions rows to aws_transactions_source to SQL
# Writing 1637 transactions rows to aws_transactions_source to SQL
# Writing 1646 transactions rows to aws_transactions_source to SQL
# Writing 1659 transactions rows to aws_transactions_source to SQL
# Writing 1661 transactions rows to aws_transactions_source to SQL
# Writing 1662 transactions rows to aws_transactions_source to SQL
# Writing 1675 transactions rows to aws_transactions_source to SQL
# Writing 1675 transactions rows to aws_transactions_source to SQL
# Writing 1675 transactions rows to aws_transactions_source to SQL
# Writing 1678 transactions rows to aws_transactions_source to SQL
# Writing 1678 transactions rows to aws_transactions_source to SQL
# Writing 1691 transactions rows to aws_transactions_source to SQL
# Writing 1693 transactions rows to aws_transactions_source to SQL
# Writing 1694 transactions rows to aws_transactions_source to SQL
# Writing 1694 transactions rows to aws_transactions_source to SQL
# Writing 1694 transactions rows to aws_transactions_source to SQL
# Writing 1696 transactions rows to aws_transactions_source to SQL
# Writing 1713 transactions rows to aws_transactions_source to SQL
# Writing 1736 transactions rows to aws_transactions_source to SQL
# Writing 1737 transactions rows to aws_transactions_source to SQL
# Writing 1751 transactions rows to aws_transactions_source to SQL
# Writing 1751 transactions rows to aws_transactions_source to SQL
# Writing 1751 transactions rows to aws_transactions_source to SQL
# Writing 1755 transactions rows to aws_transactions_source to SQL
# Writing 1446 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1443 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1412 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1351 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1337 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1345 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1424 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1367 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1347 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1401 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1448 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1436 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1414 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1436 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1280 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1500 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1398 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1296 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1467 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1369 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1387 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1439 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1344 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1440 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1405 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1466 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1476 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1464 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1369 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1391 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1266 twitter_data rows to aws_twitter_data_source to SQL
# Writing 1343 twitter_data rows to aws_twitter_data_source to SQL

# %%
for i in s3_keys:
    if 'validated' in i:
        if len(i.split('/')) == 4:
            print(i)
# Out:
# adv_stats/validated/02/adv_stats-2022-02-26.parquet
# adv_stats/validated/02/adv_stats-2022-02-27.parquet
# adv_stats/validated/02/adv_stats-2022-02-28.parquet
# adv_stats/validated/02/adv_stats-2022-03-01.parquet
# adv_stats/validated/03/adv_stats-2022-03-02.parquet
# adv_stats/validated/03/adv_stats-2022-03-03.parquet
# adv_stats/validated/03/adv_stats-2022-03-04.parquet
# adv_stats/validated/03/adv_stats-2022-03-05.parquet
# adv_stats/validated/03/adv_stats-2022-03-06.parquet
# adv_stats/validated/03/adv_stats-2022-03-07.parquet
# adv_stats/validated/03/adv_stats-2022-03-08.parquet
# adv_stats/validated/03/adv_stats-2022-03-09.parquet
# adv_stats/validated/03/adv_stats-2022-03-10.parquet
# adv_stats/validated/03/adv_stats-2022-03-11.parquet
# adv_stats/validated/03/adv_stats-2022-03-12.parquet
# adv_stats/validated/03/adv_stats-2022-03-13.parquet
# adv_stats/validated/03/adv_stats-2022-03-14.parquet
# adv_stats/validated/03/adv_stats-2022-03-15.parquet
# adv_stats/validated/03/adv_stats-2022-03-16.parquet
# adv_stats/validated/03/adv_stats-2022-03-17.parquet
# adv_stats/validated/03/adv_stats-2022-03-18.parquet
# adv_stats/validated/03/adv_stats-2022-03-19.parquet
# adv_stats/validated/03/adv_stats-2022-03-20.parquet
# adv_stats/validated/03/adv_stats-2022-03-21.parquet
# adv_stats/validated/03/adv_stats-2022-03-22.parquet
# adv_stats/validated/03/adv_stats-2022-03-23.parquet
# adv_stats/validated/03/adv_stats-2022-03-24.parquet
# adv_stats/validated/03/adv_stats-2022-03-25.parquet
# adv_stats/validated/03/adv_stats-2022-03-26.parquet
# adv_stats/validated/03/adv_stats-2022-03-27.parquet
# adv_stats/validated/03/adv_stats-2022-03-28.parquet
# adv_stats/validated/03/adv_stats-2022-03-29.parquet
# boxscores/validated/02/boxscores-2022-02-26.parquet
# boxscores/validated/02/boxscores-2022-02-27.parquet
# boxscores/validated/02/boxscores-2022-02-28.parquet
# boxscores/validated/02/boxscores-2022-03-01.parquet
# boxscores/validated/03/boxscores-2022-03-02.parquet
# boxscores/validated/03/boxscores-2022-03-03.parquet
# boxscores/validated/03/boxscores-2022-03-04.parquet
# boxscores/validated/03/boxscores-2022-03-05.parquet
# boxscores/validated/03/boxscores-2022-03-06.parquet
# boxscores/validated/03/boxscores-2022-03-07.parquet
