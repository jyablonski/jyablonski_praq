# %%
import pandas as pd

# %%
df = pd.read_csv("prac.csv")
df
# Out:
#     Unnamed: 0                 player team location opponent outcome     mp  \
# 0            0            Luka Doncic  DAL        A      NOP       W  38:02
# 1            1            Joel Embiid  PHI        A      MIL       W  37:03
# 2            2  Giannis Antetokounmpo  MIL        H      PHI       L  39:06
# 3            3            CJ McCollum  NOP        H      DAL       L  39:39
# 4            4           Luke Kennard  LAC        H      HOU       W  22:51
# ..         ...                    ...  ...      ...      ...     ...    ...
# 93          93            Danny Green  PHI        A      MIL       W  13:52
# 94          94          Davis Bertans  DAL        A      NOP       W  17:26
# 95          95      Haywood Highsmith  MIA        A      CHA       W  13:58
# 96          96             Kyle Kuzma  WAS        A      BKN       W  30:16
# 97          97              Max Strus  MIA        A      CHA       W  13:56
#
#      fgm   fga  fgpercent  ...  stl  blk  tov   pf   pts  plusminus  gmsc  \
# 0   17.0  35.0      0.486  ...  0.0  1.0  5.0  3.0  49.0       21.0  34.7
# 1   14.0  21.0      0.667  ...  1.0  0.0  6.0  5.0  42.0       13.0  33.2
# 2   13.0  23.0      0.565  ...  3.0  1.0  3.0  4.0  32.0       -9.0  31.0
# 3   14.0  26.0      0.538  ...  2.0  0.0  4.0  2.0  38.0        4.0  26.7
# 4    8.0  11.0      0.727  ...  2.0  0.0  2.0  2.0  25.0       17.0  21.8
# ..   ...   ...        ...  ...  ...  ...  ...  ...   ...        ...   ...
# 93   1.0   4.0      0.250  ...  0.0  0.0  0.0  3.0   2.0       -5.0  -0.9
# 94   1.0   7.0      0.143  ...  0.0  0.0  0.0  2.0   3.0       -2.0  -1.0
# 95   2.0   7.0      0.286  ...  0.0  0.0  1.0  1.0   4.0      -25.0  -1.3
# 96   2.0   7.0      0.286  ...  1.0  0.0  8.0  3.0   5.0       10.0  -1.7
# 97   1.0   6.0      0.167  ...  0.0  0.0  0.0  1.0   2.0      -20.0  -1.9
#
#           date            type  season
# 0   2022-02-21  Regular Season    2022
# 1   2022-02-21  Regular Season    2022
# 2   2022-02-21  Regular Season    2022
# 3   2022-02-21  Regular Season    2022
# 4   2022-02-21  Regular Season    2022
# ..         ...             ...     ...
# 93  2022-02-21  Regular Season    2022
# 94  2022-02-21  Regular Season    2022
# 95  2022-02-21  Regular Season    2022
# 96  2022-02-21  Regular Season    2022
# 97  2022-02-21  Regular Season    2022
#
# [98 rows x 30 columns]

# %%
df['player'] = df['player'].str.replace(" Jr.", "", regex = True)
df['player'] = df['player'].str.replace(" Sr.", "", regex = True)
df['player'] = df['player'].str.replace(" II", "", regex = True)
df['player'] = df['player'].str.replace(" III", "", regex = True)
df['player'] = df['player'].str.replace(" IV", "", regex = True)

# %%
def clean_player_names(col: pd.Series) -> pd.Series:
